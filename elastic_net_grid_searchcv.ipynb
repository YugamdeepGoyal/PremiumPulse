# %%
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import ElasticNet
from load_data import get_dataset
from pipeline import get_preprocessor
from print_metric import print_results

# %%
X_train, X_test, y_train, y_test = get_dataset()

# %%
preprocessor = get_preprocessor()

# %%
pipe = Pipeline([
    ("preprocessor", preprocessor),
    ("model", ElasticNet(max_iter=300000))
])

# %%
params_grid = {
    "model__alpha": [0.001, 0.01, 0.1, 1, 10, 100],
    "model__l1_ratio": [0.1, 0.5, 0.9, 0.95, 0.99]
}

# %%
grid = GridSearchCV(pipe, param_grid=params_grid, cv=5, scoring="neg_mean_absolute_error", verbose=1, n_jobs=-1)

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         Pipeline(steps=[('feature_engineer',
#                                                          FunctionTransformer(func=<function add_features at 0x11b9a9640>)),
#                                                         ('column_transformer',
#                                                          ColumnTransformer(transformers=[('passthrough',
#                                                                                           Pipeline(steps=[('scaler',
#                                                                                                            StandardScaler())]),
#                                                                                           ['age',
#                                                                                            'bmi',
#                                                                                            'children',
#                                                                                            'smoker_bmi',
#                                                                                            'smoker_obese']),
#                                                                                          ('encoder',
#                                                                                           Pipeline(steps=[('encoder',
#                                                                                                            OneHotEncoder(handle_unknown='ignore'))]),
#                                                                                           ['sex',
#                                                                                            'smoker',
#                                                                                            'region'])]))])),
#                                        ('model', ElasticNet(max_iter=300000))]),
#              n_jobs=-1,
#              param_grid={'model__alpha': [0.001, 0.01, 0.1, 1, 10, 100],
#                          'model__l1_ratio': [0.1, 0.5, 0.9, 0.95, 0.99]},
#              scoring='neg_mean_absolute_error', verbose=1)

# %%
y_pred = grid.predict(X_test)

# %%
grid.best_params_
# Out:
# {'model__alpha': 0.001, 'model__l1_ratio': 0.99}

# %%
print("Training")
print_results(y_train, grid.predict(X_train))
print("\n")
print("Testing")
print_results(y_test, y_pred)
# Out:
# Training
# R2 Score 0.8670173616271875
# MAE 2354.233501802794
# MSE 19294503.37260393
# RMSE 4392.550895846733
#
#
# Testing
# R2 Score 0.8689981976178562
# MAE 2391.0522717277227
# MSE 19767011.264793828
# RMSE 4446.010713526659

# %%
plt.title("Residual Plot of Elastic Net with Grid Search CV")
residuals = y_test - y_pred
plt.scatter(y_pred, residuals)
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.axhline(y=0, color='r', linestyle='--')
plt.tight_layout()
plt.savefig("images/residual_plot_of_elastic_net_grid_search.png", dpi=1200)
plt.show()
