# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, OrdinalEncoder, StandardScaler, FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, cross_val_score
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, root_mean_squared_error
from sklearn.linear_model import LinearRegression, ElasticNet, LassoCV
from load_data import get_dataset
from pipeline import get_preprocessor

# %%
X_train, X_test, y_train, y_test = get_dataset()

# %%
preprocessor = get_preprocessor()

# %%
alpha_grid = np.logspace(-4, 2, 100)
pipe = Pipeline([
    ("preprocessor", preprocessor),
    ("model", LassoCV(max_iter=300000, alphas=alpha_grid, cv=5, verbose=1, n_jobs=-1, random_state=42))
])

# %%
pipe.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 10 concurrent workers.
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................[Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.0s finished
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('passthrough',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
# ...

# %%
y_pred = pipe.predict(X_test)

# %%
pipe.named_steps
# Out:
# {'preprocessor': ColumnTransformer(transformers=[('passthrough',
#                                   Pipeline(steps=[('scaler', StandardScaler())]),
#                                   ['age', 'bmi', 'children']),
#                                  ('encoder',
#                                   Pipeline(steps=[('encoder',
#                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                   ['sex', 'smoker', 'region'])]),
#  'model': LassoCV(alphas=array([1.00000000e-04, 1.14975700e-04, 1.32194115e-04, 1.51991108e-04,
#         1.74752840e-04, 2.00923300e-04, 2.31012970e-04, 2.65608778e-04,
#         3.05385551e-04, 3.51119173e-04, 4.03701726e-04, 4.64158883e-04,
#         5.33669923e-04, 6.13590727e-04, 7.05480231e-04, 8.11130831e-04,
#         9.32603347e-04, 1.07226722e-03, 1.23284674e-03, 1.41747416e-03,
#         1.62975083e-03, 1.87381742e-0...
# ...

# %%
pipe["model"].alpha_
# Out:
# np.float64(75.64633275546291)

# %%
print("Training")
print("R2 score", r2_score(y_train, pipe.predict(X_train)))
print("Mean absolute error", mean_absolute_error(y_train, pipe.predict(X_train)))
print("Mean squared error", mean_squared_error(y_train, pipe.predict(X_train)))
print("Root mean squared error", root_mean_squared_error(y_train, pipe.predict(X_train)))

print("Testing")
print("R2 score", r2_score(y_test, y_pred))
print("Mean absolute error", mean_absolute_error(y_test, y_pred))
print("Mean squared error", mean_squared_error(y_test, y_pred))
print("Root mean squared error", root_mean_squared_error(y_test, y_pred))
# Out:
# Training
# R2 score 0.74411801148779
# Mean absolute error 4197.939077699871
# Mean squared error 37126018.48443096
# Root mean squared error 6093.1123807485255
# Testing
# R2 score 0.7649089069189721
# Mean absolute error 4280.710018218042
# Mean squared error 35473162.969388194
# Root mean squared error 5955.935104531294

# %%
plt.title("Residual Plot of LassoCV")
residuals = y_test - y_pred
plt.scatter(y_pred, residuals)
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.axhline(y=0, color='r', linestyle='--')
plt.tight_layout()
plt.savefig("images/residual_plot_of_lassocv.png", dpi=1200)
plt.show()
