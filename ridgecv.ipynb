# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, root_mean_squared_error
from sklearn.linear_model import RidgeCV
from load_data import get_dataset
from pipeline import get_preprocessor

# %%
X_train, X_test, y_train, y_test = get_dataset()

# %%
preprocessor = get_preprocessor()

# %%
alpha_grid = np.logspace(-4, 4, 100)
pipe = Pipeline([
    ("preprocessor", preprocessor),
    ("model", RidgeCV(alphas=alpha_grid, cv=5, scoring="neg_mean_absolute_error"))
])

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  Pipeline(steps=[('feature_engineer',
#                                   FunctionTransformer(func=<function add_features at 0x11f001590>)),
#                                  ('column_transformer',
#                                   ColumnTransformer(transformers=[('passthrough',
#                                                                    Pipeline(steps=[('scaler',
#                                                                                     StandardScaler())]),
#                                                                    ['age',
#                                                                     'bmi',
#                                                                     'children',
#                                                                     'smoker_bmi',
#                                                                     'smoker_obese']),
#                                                                   ('encoder',
#                                                                    Pipeline(steps=[('encoder',
#                                                                                     OneHotEncode...
#        1.38488637e+02, 1.66810054e+02, 2.00923300e+02, 2.42012826e+02,
#        2.91505306e+02, 3.51119173e+02, 4.22924287e+02, 5.09413801e+02,
#        6.13590727e+02, 7.39072203e+02, 8.90215085e+02, 1.07226722e+03,
#        1.29154967e+03, 1.55567614e+03, 1.87381742e+03, 2.25701972e+03,
#        2.71858824e+03, 3.27454916e+03, 3.94420606e+03, 4.75081016e+03,
#        5.72236766e+03, 6.89261210e+03, 8.30217568e+03, 1.00000000e+04]),
#                          cv=5, scoring='neg_mean_absolute_error'))])

# %%
y_pred = pipe.predict(X_test)

# %%
pipe["model"].alpha_
# Out:
# np.float64(0.0001)

# %%
print("Training")
print("R2 score", r2_score(y_train, pipe.predict(X_train)))
print("Mean absolute error", mean_absolute_error(y_train, pipe.predict(X_train)))
print("Mean squared error", mean_squared_error(y_train, pipe.predict(X_train)))
print("Root mean squared error", root_mean_squared_error(y_train, pipe.predict(X_train)))
print("\n")
print("Testing")
print("R2 score", r2_score(y_test, y_pred))
print("Mean absolute error", mean_absolute_error(y_test, y_pred))
print("Mean squared error", mean_squared_error(y_test, y_pred))
print("Root mean squared error", root_mean_squared_error(y_test, y_pred))
# Out:
# Training
# R2 score 0.8670173618722599
# Mean absolute error 2354.226556540866
# Mean squared error 19294503.33704628
# Root mean squared error 4392.550891799238
#
#
# Testing
# R2 score 0.8689986562834042
# Mean absolute error 2391.0445000969066
# Mean squared error 19766942.056226544
# Root mean squared error 4446.002930298916

# %%
plt.title("Residual Plot of RidgeCV")
residuals = y_test - y_pred
plt.scatter(y_pred, residuals)
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.axhline(y=0, color='r', linestyle='--')
plt.tight_layout()
plt.savefig("images/residual_plot_of_ridgecv.png", dpi=1200)
plt.show()
