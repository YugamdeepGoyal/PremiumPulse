# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, OrdinalEncoder, StandardScaler, FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, cross_val_score
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, root_mean_squared_error
from sklearn.linear_model import LinearRegression, RidgeCV
from load_data import get_dataset
from pipeline import get_preprocessor

# %%
X_train, X_test, y_train, y_test = get_dataset()

# %%
preprocessor = get_preprocessor()

# %%
alpha_grid = np.logspace(-4, 4, 100)
pipe = Pipeline([
    ("preprocessor", preprocessor),
    ("model", RidgeCV(alphas=alpha_grid, cv=5, scoring="neg_mean_absolute_error"))
])

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('passthrough',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'bmi', 'children']),
#                                                  ('encoder',
#                                                   Pipeline(steps=[('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['sex', 'smoker',
#                                                    'region'])])),
#                 ('model',
#                  RidgeCV(alphas=array([1.00000000e-04, 1.20450354e-04, 1.45082878e-04, 1.74752840e-0...
#        1.38488637e+02, 1.66810054e+02, 2.00923300e+02, 2.42012826e+02,
#        2.91505306e+02, 3.51119173e+02, 4.22924287e+02, 5.09413801e+02,
#        6.13590727e+02, 7.39072203e+02, 8.90215085e+02, 1.07226722e+03,
#        1.29154967e+03, 1.55567614e+03, 1.87381742e+03, 2.25701972e+03,
#        2.71858824e+03, 3.27454916e+03, 3.94420606e+03, 4.75081016e+03,
#        5.72236766e+03, 6.89261210e+03, 8.30217568e+03, 1.00000000e+04]),
#                          cv=5, scoring='neg_mean_absolute_error'))])

# %%
y_pred = pipe.predict(X_test)

# %%
pipe["model"].alpha_
# Out:
# np.float64(0.0001)

# %%
print("Training")
print("R2 score", r2_score(y_train, pipe.predict(X_train)))
print("Mean absolute error", mean_absolute_error(y_train, pipe.predict(X_train)))
print("Mean squared error", mean_squared_error(y_train, pipe.predict(X_train)))
print("Root mean squared error", root_mean_squared_error(y_train, pipe.predict(X_train)))
# Out:
# Training
# R2 score 0.7449555328227927
# Mean absolute error 4183.153817004527
# Mean squared error 37004502.184103586
# Root mean squared error 6083.13259629474

# %%
print("Testing")
print("R2 score", r2_score(y_test, y_pred))
print("Mean absolute error", mean_absolute_error(y_test, y_pred))
print("Mean squared error", mean_squared_error(y_test, y_pred))
print("Root mean squared error", root_mean_squared_error(y_test, y_pred))
# Out:
# Testing
# R2 score 0.7672642826611256
# Mean absolute error 4243.654716515683
# Mean squared error 35117757.63922217
# Root mean squared error 5926.023762964689

# %%
plt.title("Residual Plot of RidgeCV")
residuals = y_test - y_pred
plt.scatter(y_pred, residuals)
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.axhline(y=0, color='r', linestyle='--')
plt.tight_layout()
plt.savefig("images/residual_plot_of_ridgecv.png", dpi=1200)
plt.show()
